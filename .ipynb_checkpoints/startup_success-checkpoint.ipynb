# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt 
import csv
import seaborn

# %%
df = pd.read_csv('Data.csv', encoding='latin1') 
df.head(100)
# Out:
#    Company_Name Dependent-Company Status year of founding  \
# 0      Company1                  Success          No Info
# 1      Company2                  Success             2011
# 2      Company3                  Success             2011
# 3      Company4                  Success             2009
# 4      Company5                  Success             2010
# ..          ...                      ...              ...
# 95    Company96                  Success             2011
# 96    Company97                  Success             2012
# 97    Company98                  Success             2012
# 98    Company99                  Success             2012
# 99   Company100                  Success             2012
#
#    Age of company in years  Internet Activity Score  \
# 0                  No Info                     -1.0
# 1                        3                    125.0
# 2                        3                    455.0
# 3                        5                    -99.0
# 4                        4                    496.0
# ..                     ...                      ...
# 95                       3                     53.0
# 96                       2                    504.0
# 97                       2                    661.0
# 98                       2                      NaN
# 99                       2                    220.0
#
#       Short Description of company profile  \
# 0                       Video distribution
# 1                                      NaN
# 2                 Event Data Analytics API
# 3   The most advanced analytics for mobile
# 4    The Location-Based Marketing Platform
# ..                                     ...
# 95                                     NaN
# 96                                     NaN
# 97                                     NaN
# 98                                     NaN
# 99                                     NaN
#
#                                Industry of company Focus functions of company  \
# 0                                              NaN                  operation
# 1           Market Research|Marketing|Crowdfunding           Marketing, sales
# 2   Analytics|Cloud Computing|Software Development                 operations
# 3                                 Mobile|Analytics          Marketing & Sales
# 4          Analytics|Marketing|Enterprise Software          Marketing & Sales
# ..                                             ...                        ...
# 95                             Enterprise Software                  marketing
# 96                                             NaN               social media
# 97                                     Real Estate                      sales
# 98                                             NaN                    service
# 99                                      E-Commerce                    service
#
#                                             Investors  Employee Count  ...  \
# 0   KPCB Holdings|Draper Fisher Jurvetson (DFJ)|Kl...             3.0  ...
# 1                                                 NaN             NaN  ...
# 2   TechStars|Streamlined Ventures|Amplify Partner...            14.0  ...
# 3   Michael Birch|Max Levchin|Sequoia Capital|Keit...            45.0  ...
# 4   DFJ Frontier|Draper Nexus Ventures|Gil Elbaz|A...            39.0  ...
# ..                                                ...             ...  ...
# 95       500 Startups|Tech Wildcatters|Start-Up Chile             8.0  ...
# 96                                                NaN             NaN  ...
# 97                             Nexus Venture Partners             NaN  ...
# 98                                                NaN             NaN  ...
# 99        500 Startups|Karamveer Singh|Dinesh Tejwani             6.0  ...
#
#     Percent_skill_Data Science Percent_skill_Business Strategy  \
# 0                            0                               0
# 1                  8.823529412                     21.76470588
# 2                  3.846153846                     17.09401709
# 3                            0                               0
# 4                            0                               0
# ..                         ...                             ...
# 95                 25.50505051                     12.87878788
# 96                           0                               0
# 97                           0                               0
# 98                           0                     2.941176471
# 99                           0                     8.333333333
#
#    Percent_skill_Product Management Percent_skill_Sales  Percent_skill_Domain  \
# 0                                 0                   0                     0
# 1                       10.88235294         2.941176471                     0
# 2                       9.401709402                   0           2.777777778
# 3                                 0                   0                     0
# 4                                 0                   0                     0
# ..                              ...                 ...                   ...
# 95                      7.323232323         4.545454545                     0
# 96                                0                   0                     0
# 97                                0                   0                     0
# 98                                0                   0           2.941176471
# 99                      8.333333333                   0           16.66666667
#
#    Percent_skill_Law Percent_skill_Consulting Percent_skill_Finance  \
# 0                  0                        0                     0
# 1                  0                        0                     0
# 2                  0                        0                     0
# 3                  0                        0                     0
# 4                  0                        0                     0
# ..               ...                      ...                   ...
# 95                 0              4.545454545                     0
# 96                 0                        0                     0
# 97                 0                        0                     0
# 98                 0                        0                     0
# 99                 0                        0                     0
#
#    Percent_skill_Investment  Renown score
# 0                         0             0
# 1                         0             8
# 2                         0             9
# 3                         0             5
# 4                         0             6
# ..                      ...           ...
# 95                        0             3
# 96                        0             0
# 97                        0             0
# 98                        0             4
# 99                        0             2
#
# [100 rows x 116 columns]

# %%
df['Percent_skill_Finance'].nunique()
# Out:
# 30

# %%
df['Dependent-Company Status'].isnull().sum() #all have labels
# Out:
# 0

# %%
df['Percent_skill_Finance'].isnull().sum()#no nan values,instead the following code shows that there are "No Info" values
# Out:
# 0

# %%
value_count = (df["Percent_skill_Finance"] == "No Info").sum() # 61 "No Info" values
value_count
# Out:
# 61

# %%
df_1 = df[df["Percent_skill_Finance"] == "No Info"]['Dependent-Company Status']
df_1.value_counts()
# Out:
# Dependent-Company Status
# Failed     58
# Success     3
# Name: count, dtype: int64

# %%
df['Dependent-Company Status'].value_counts()
# Out:
# Dependent-Company Status
# Success    305
# Failed     167
# Name: count, dtype: int64

# %% [markdown]
# #### from the above two codes we see that failed businesses are 167 , and remove "No Info" rows which contain 58 failed data of businesses should be wrong action

# %%
df['Percent_skill_Finance'].value_counts()
# Out:
# Percent_skill_Finance
# 0              360
# No Info         61
# 11.11111111      7
# 2.777777778      5
# 5.555555556      5
# 7.142857143      4
# 5.882352941      4
# 16.66666667      2
# 1.851851852      2
# 4.761904762      2
# 37.5             1
# 47.05882353      1
# 3.333333333      1
# 3.571428571      1
# 29.41176471      1
# 23.80952381      1
# 5                1
# 7.407407407      1
# 3.03030303       1
# 6.666666667      1
# 33.33333333      1
# 12.5             1
# 41.17647059      1
# 27.77777778      1
# 14.70588235      1
# 78.57142857      1
# 10.88235294      1
# 36.84210526      1
# 4.444444444      1
# 9.090909091      1
# Name: count, dtype: int64

# %%
Dependent_Company_Status = df.loc[df["Percent_skill_Finance"].isna(), "Dependent-Company Status"]
Dependent_Company_Status #no nan rows so there is nothing to show
# Out:
# Series([], Name: Dependent-Company Status, dtype: object)

# %%
df.info() #3 ints and 5 floats. total 8 numerics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Columns: 116 entries, Company_Name to Renown score
# dtypes: float64(5), int64(3), object(108)
# memory usage: 427.9+ KB

# %%
df.describe() #as only 8 features are numeric the below table has 8 columns
# Out:
#        Internet Activity Score  Employee Count  Employees count MoM change  \
# count               407.000000      306.000000                  267.000000
# mean                114.159705       31.408497                   -1.299625
# std                 225.651419       62.673600                   23.967085
# min                -725.000000        0.000000                 -100.000000
# 25%                  -3.500000        4.250000                    0.000000
# 50%                  60.000000       13.000000                    0.000000
# 75%                 216.000000       31.000000                    6.000000
# max                1535.000000      594.000000                   50.000000
#
#        Last Funding Amount  Number of Co-founders  Number of of advisors  \
# count         3.120000e+02             472.000000             472.000000
# mean          6.379489e+06               1.868644               1.016949
# std           9.901622e+06               1.143481               2.014736
# min           1.000000e+04               0.000000               0.000000
# 25%           7.500000e+05               1.000000               0.000000
# 50%           2.800000e+06               2.000000               0.000000
# 75%           7.850000e+06               2.250000               1.000000
# max           7.700000e+07               7.000000              13.000000
#
#        Team size Senior leadership  Industry trend in investing
# count                   472.000000                   390.000000
# mean                      3.730932                     2.889744
# std                       2.516539                     0.845765
# min                       1.000000                     0.000000
# 25%                       2.000000                     2.000000
# 50%                       3.000000                     3.000000
# 75%                       5.000000                     3.000000
# max                      24.000000                     5.000000

# %%
df['Dependent-Company Status'].unique() #all have labels ,there is nothing to remove
# Out:
# array(['Success', 'Failed'], dtype=object)

# %%
df['Dependent-Company Status'].isnull().any() #to be convinced ...
# Out:
# False

# %%
df['Dependent-Company Status'].nunique() #just fail and success
# Out:
# 2

# %%
df['Dependent-Company Status'].value_counts() #305 succeded 167 failed
# Out:
# Dependent-Company Status
# Success    305
# Failed     167
# Name: count, dtype: int64

# %%
df['Percent_skill_Entrepreneurship'].value_counts()
# Out:
# Percent_skill_Entrepreneurship
# 0              131
# No Info         61
# 11.11111111     30
# 16.66666667     19
# 5.555555556     19
#               ...
# 9.490740741      1
# 6.944444444      1
# 8.496732026      1
# 14.28571429      1
# 5.664488017      1
# Name: count, Length: 93, dtype: int64

# %%
df.isnull().sum()
# Out:
# Company_Name                 0
# Dependent-Company Status     0
# year of founding             0
# Age of company in years     44
# Internet Activity Score     65
#                             ..
# Percent_skill_Law            0
# Percent_skill_Consulting     0
# Percent_skill_Finance        0
# Percent_skill_Investment     0
# Renown score                 0
# Length: 116, dtype: int64

# %%
df.head()
# Out:
#   Company_Name Dependent-Company Status year of founding  \
# 0     Company1                  Success          No Info
# 1     Company2                  Success             2011
# 2     Company3                  Success             2011
# 3     Company4                  Success             2009
# 4     Company5                  Success             2010
#
#   Age of company in years  Internet Activity Score  \
# 0                 No Info                     -1.0
# 1                       3                    125.0
# 2                       3                    455.0
# 3                       5                    -99.0
# 4                       4                    496.0
#
#      Short Description of company profile  \
# 0                      Video distribution
# 1                                     NaN
# 2                Event Data Analytics API
# 3  The most advanced analytics for mobile
# 4   The Location-Based Marketing Platform
#
#                               Industry of company Focus functions of company  \
# 0                                             NaN                  operation
# 1          Market Research|Marketing|Crowdfunding           Marketing, sales
# 2  Analytics|Cloud Computing|Software Development                 operations
# 3                                Mobile|Analytics          Marketing & Sales
# 4         Analytics|Marketing|Enterprise Software          Marketing & Sales
#
#                                            Investors  Employee Count  ...  \
# 0  KPCB Holdings|Draper Fisher Jurvetson (DFJ)|Kl...             3.0  ...
# 1                                                NaN             NaN  ...
# 2  TechStars|Streamlined Ventures|Amplify Partner...            14.0  ...
# 3  Michael Birch|Max Levchin|Sequoia Capital|Keit...            45.0  ...
# 4  DFJ Frontier|Draper Nexus Ventures|Gil Elbaz|A...            39.0  ...
#
#    Percent_skill_Data Science Percent_skill_Business Strategy  \
# 0                           0                               0
# 1                 8.823529412                     21.76470588
# 2                 3.846153846                     17.09401709
# 3                           0                               0
# 4                           0                               0
#
#   Percent_skill_Product Management Percent_skill_Sales  Percent_skill_Domain  \
# 0                                0                   0                     0
# 1                      10.88235294         2.941176471                     0
# 2                      9.401709402                   0           2.777777778
# 3                                0                   0                     0
# 4                                0                   0                     0
#
#   Percent_skill_Law Percent_skill_Consulting Percent_skill_Finance  \
# 0                 0                        0                     0
# 1                 0                        0                     0
# 2                 0                        0                     0
# 3                 0                        0                     0
# 4                 0                        0                     0
#
#   Percent_skill_Investment  Renown score
# 0                        0             0
# 1                        0             8
# 2                        0             9
# 3                        0             5
# 4                        0             6
#
# [5 rows x 116 columns]

# %%
df['year of founding'].dtype   
df['Percent_skill_Data Science'].dtype #there are numeric values which are still object dtype
# Out:
# dtype('O')

# %%
df['year of founding'].dtype
df['Age of company in years'].dtype #both are aobect dtype,to count corr it is required to alter dtype
# Out:
# dtype('O')

# %%
df['year of founding'] = pd.to_numeric(df['year of founding'], errors='coerce')  # Convert to int
df['Age of company in years'] = pd.to_numeric(df['Age of company in years'],errors='coerce')

# %%
df['year of founding'].corr(df['Age of company in years'])
# Out:
# -0.9999999999999984

# %%
#above we see that 'Age of company in years' and 'year of founding' are. highly correlated 
#so we can drop(remove) one of them.

# %%
df['Age of company in years'].isna().sum()
# Out:
# 59

# %%
df['year of founding'].isna().sum()
# Out:
# 59

# %%
#both columns have exactly 59 nan values. i assume that they correspond to each other.howeveer let't check...

# %%
nan_year_of_founding= df['year of founding'].isna()
nan_Age_of_company_in_years = df['Age of company in years'].isna()
nan_correlation = nan_year_of_founding == nan_Age_of_company_in_years
nan_correlation.value_counts() #all values are true ,so 
# means that the positions of NaN values in both Column1 and Column2 are exactly the same
# Out:
# True    472
# Name: count, dtype: int64

# %%
dict = pd.read_csv('dictionary.csv')
dict
# Out:
#                      Variable  \
# 0                Company_Name
# 1    Dependent-Company Status
# 2            year of founding
# 3     Age of company in years
# 4     Internet Activity Score
# ..                        ...
# 111         Percent_skill_Law
# 112  Percent_skill_Consulting
# 113     Percent_skill_Finance
# 114  Percent_skill_Investment
# 115              Renown score
#
#                                            Description
# 0                                                  NaN
# 1    Dependent variable indicating if company succe...
# 2                                                  NaN
# 3                                                  NaN
# 4          How much company is acgtive on social media
# ..                                                 ...
# 111                          for founders & cofounders
# 112                          for founders & cofounders
# 113                          for founders & cofounders
# 114                          for founders & cofounders
# 115                          for founders & cofounders
#
# [116 rows x 2 columns]

# %%
dict.dropna(axis = "index")
# Out:
#                                               Variable  \
# 1                             Dependent-Company Status
# 4                              Internet Activity Score
# 8                                            Investors
# 24                       Number of of repeat investors
# 27    Average size of companies worked for in the past
# 28             Have been part of startups in the past?
# 29   Have been part of successful startups in the p...
# 30          Was he or she partner in Big 5 consulting?
# 31                              Consulting experience?
# 57                           Exposure across the globe
# 58              Breadth of experience across verticals
# 59                                   Highest education
# 60                                  Years of education
# 61                 Specialization of highest education
# 62                   Relevance of education to venture
# 63                  Relevance of experience to venture
# 64          Degree from a Tier 1 or Tier 2 university?
# 65                     Renowned in professional circle
# 66         Experience in selling and building products
# 67             Experience in Fortune 100 organizations
# 68             Experience in Fortune 500 organizations
# 69            Experience in Fortune 1000 organizations
# 70                           Top management similarity
# 71   Number of Recognitions for Founders and Co-fou...
# 72                 Number of  of Research publications
# 73                                        Skills score
# 101                     Percent_skill_Entrepreneurship
# 102                           Percent_skill_Operations
# 103                          Percent_skill_Engineering
# 104                            Percent_skill_Marketing
# 105                           Percent_skill_Leadership
# 106                         Percent_skill_Data Science
# 107                    Percent_skill_Business Strategy
# 108                   Percent_skill_Product Management
# 109                                Percent_skill_Sales
# 110                               Percent_skill_Domain
# 111                                  Percent_skill_Law
# 112                           Percent_skill_Consulting
# 113                              Percent_skill_Finance
# 114                           Percent_skill_Investment
# 115                                       Renown score
#
#                                            Description
# 1    Dependent variable indicating if company succe...
# 4          How much company is acgtive on social media
# 8                                    List of investors
# 24     Number of investors who invested multiple times
# 27                           for founders & cofounders
# 28                           for founders & cofounders
# 29                           for founders & cofounders
# 30                           for founders & cofounders
# 31                           for founders & cofounders
# 57                           for founders & cofounders
# 58                           for founders & cofounders
# 59                           for founders & cofounders
# 60                           for founders & cofounders
# 61                           for founders & cofounders
# 62                           for founders & cofounders
# 63                           for founders & cofounders
# 64                           for founders & cofounders
# 65                           for founders & cofounders
# 66                           for founders & cofounders
# 67                           for founders & cofounders
# 68                           for founders & cofounders
# 69                           for founders & cofounders
# 70                           for founders & cofounders
# 71                           for founders & cofounders
# 72                           for founders & cofounders
# 73                           for founders & cofounders
# 101                          for founders & cofounders
# 102                          for founders & cofounders
# 103                          for founders & cofounders
# 104                          for founders & cofounders
# 105                          for founders & cofounders
# 106                          for founders & cofounders
# 107                          for founders & cofounders
# 108                          for founders & cofounders
# 109                          for founders & cofounders
# 110                          for founders & cofounders
# 111                          for founders & cofounders
# 112                          for founders & cofounders
# 113                          for founders & cofounders
# 114                          for founders & cofounders
# 115                          for founders & cofounders

# %%
df['Average size of companies worked for in the past'].unique()
# Out:
# array(['Small', 'Large', 'Medium', 'No Info'], dtype=object)

# %%
df['Average size of companies worked for in the past'].value_counts()
# Out:
# Average size of companies worked for in the past
# Small      228
# Medium     130
# Large       83
# No Info     31
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company_Name Dependent-Company Status  year of founding  \
# 0     Company1                  Success               NaN
# 1     Company2                  Success            2011.0
# 2     Company3                  Success            2011.0
# 3     Company4                  Success            2009.0
# 4     Company5                  Success            2010.0
#
#    Age of company in years  Internet Activity Score  \
# 0                      NaN                     -1.0
# 1                      3.0                    125.0
# 2                      3.0                    455.0
# 3                      5.0                    -99.0
# 4                      4.0                    496.0
#
#      Short Description of company profile  \
# 0                      Video distribution
# 1                                     NaN
# 2                Event Data Analytics API
# 3  The most advanced analytics for mobile
# 4   The Location-Based Marketing Platform
#
#                               Industry of company Focus functions of company  \
# 0                                             NaN                  operation
# 1          Market Research|Marketing|Crowdfunding           Marketing, sales
# 2  Analytics|Cloud Computing|Software Development                 operations
# 3                                Mobile|Analytics          Marketing & Sales
# 4         Analytics|Marketing|Enterprise Software          Marketing & Sales
#
#                                            Investors  Employee Count  ...  \
# 0  KPCB Holdings|Draper Fisher Jurvetson (DFJ)|Kl...             3.0  ...
# 1                                                NaN             NaN  ...
# 2  TechStars|Streamlined Ventures|Amplify Partner...            14.0  ...
# 3  Michael Birch|Max Levchin|Sequoia Capital|Keit...            45.0  ...
# 4  DFJ Frontier|Draper Nexus Ventures|Gil Elbaz|A...            39.0  ...
#
#    Percent_skill_Data Science Percent_skill_Business Strategy  \
# 0                           0                               0
# 1                 8.823529412                     21.76470588
# 2                 3.846153846                     17.09401709
# 3                           0                               0
# 4                           0                               0
#
#   Percent_skill_Product Management Percent_skill_Sales  Percent_skill_Domain  \
# 0                                0                   0                     0
# 1                      10.88235294         2.941176471                     0
# 2                      9.401709402                   0           2.777777778
# 3                                0                   0                     0
# 4                                0                   0                     0
#
#   Percent_skill_Law Percent_skill_Consulting Percent_skill_Finance  \
# 0                 0                        0                     0
# 1                 0                        0                     0
# 2                 0                        0                     0
# 3                 0                        0                     0
# 4                 0                        0                     0
#
#   Percent_skill_Investment  Renown score
# 0                        0             0
# 1                        0             8
# 2                        0             9
# 3                        0             5
# 4                        0             6
#
# [5 rows x 116 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Columns: 116 entries, Company_Name to Renown score
# dtypes: float64(7), int64(3), object(106)
# memory usage: 427.9+ KB

# %%
df.dtypes
# Out:
# Company_Name                 object
# Dependent-Company Status     object
# year of founding             object
# Age of company in years      object
# Internet Activity Score     float64
#                              ...
# Percent_skill_Law            object
# Percent_skill_Consulting     object
# Percent_skill_Finance        object
# Percent_skill_Investment     object
# Renown score                 object
# Length: 116, dtype: object

# %%
df['Renown score'].dtype
# Out:
# dtype('O')

# %%
df['Internet Activity Score'].dtype
# Out:
# dtype('float64')

# %%
df.shape
# Out:
# (472, 116)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 54752

# %%
df.duplicated(subset=None, keep='first').value_counts()
#check duplicates by rows
# Out:
# False    472
# Name: count, dtype: int64

# %%
df.drop('Company_Name',axis = 1) 

df_cleaned = df.loc[:, ~df.T.duplicated()]
df_cleaned.shape
#check duplicates by column
# Out:
# (472, 116)

# %%
#still 116 , means no duplicate column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Columns: 116 entries, Company_Name to Renown score
# dtypes: float64(7), int64(3), object(106)
# memory usage: 427.9+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
# Out:
# /Users/aramkarakhanyan/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#above again we see that 'age of company in years' and 'year of funding' are strongly correlated.

# %%
numeric_df = df.select_dtypes(include = ['float64','int64'])
non_numeric_df = df.select_dtypes(exclude =['float64','int64'])

# %%
numeric_df.head()
# Out:
#    Internet Activity Score  Employee Count  Employees count MoM change  \
# 0                     -1.0             3.0                         0.0
# 1                    125.0             NaN                         NaN
# 2                    455.0            14.0                         0.0
# 3                    -99.0            45.0                        10.0
# 4                    496.0            39.0                         3.0
#
#    Last Funding Amount  Number of Co-founders  Number of of advisors  \
# 0             450000.0                      1                      2
# 1                  NaN                      2                      0
# 2            2350000.0                      3                      0
# 3           10250000.0                      2                      0
# 4            5500000.0                      1                      1
#
#    Team size Senior leadership  Industry trend in investing
# 0                            2                          2.0
# 1                            4                          3.0
# 2                            7                          3.0
# 3                            4                          4.0
# 4                            8                          3.0

# %%
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#                              year of founding  Age of company in years  \
# year of founding                     1.000000                -1.000000
# Age of company in years             -1.000000                 1.000000
# Internet Activity Score              0.215869                -0.215869
# Employee Count                      -0.396640                 0.396640
# Employees count MoM change           0.095640                -0.095640
# Last Funding Amount                 -0.275466                 0.275466
# Number of Co-founders                0.229339                -0.229339
# Number of of advisors               -0.042000                 0.042000
# Team size Senior leadership         -0.280334                 0.280334
# Industry trend in investing         -0.009382                 0.009382
#
#                              Internet Activity Score  Employee Count  \
# year of founding                            0.215869       -0.396640
# Age of company in years                    -0.215869        0.396640
# Internet Activity Score                     1.000000        0.100511
# Employee Count                              0.100511        1.000000
# Employees count MoM change                  0.141396        0.098178
# Last Funding Amount                         0.029657        0.371511
# Number of Co-founders                       0.139881       -0.021549
# Number of of advisors                       0.089105        0.091659
# Team size Senior leadership                 0.105978        0.497193
# Industry trend in investing                 0.041369        0.043491
#
#                              Employees count MoM change  Last Funding Amount  \
# year of founding                               0.095640            -0.275466
# Age of company in years                       -0.095640             0.275466
# Internet Activity Score                        0.141396             0.029657
# Employee Count                                 0.098178             0.371511
# Employees count MoM change                     1.000000             0.120823
# Last Funding Amount                            0.120823             1.000000
# Number of Co-founders                          0.024138             0.013045
# Number of of advisors                          0.080929             0.101469
# Team size Senior leadership                    0.139582             0.376896
# Industry trend in investing                    0.199115             0.132535
#
#                              Number of Co-founders  Number of of advisors  \
# year of founding                          0.229339              -0.042000
# Age of company in years                  -0.229339               0.042000
# Internet Activity Score                   0.139881               0.089105
# Employee Count                           -0.021549               0.091659
# Employees count MoM change                0.024138               0.080929
# Last Funding Amount                       0.013045               0.101469
# Number of Co-founders                     1.000000               0.106028
# Number of of advisors                     0.106028               1.000000
# Team size Senior leadership               0.138206               0.303241
# Industry trend in investing               0.121460               0.095711
#
#                              Team size Senior leadership  \
# year of founding                               -0.280334
# Age of company in years                         0.280334
# Internet Activity Score                         0.105978
# Employee Count                                  0.497193
# Employees count MoM change                      0.139582
# Last Funding Amount                             0.376896
# Number of Co-founders                           0.138206
# Number of of advisors                           0.303241
# Team size Senior leadership                     1.000000
# Industry trend in investing                     0.166963
#
#                              Industry trend in investing
# year of founding                               -0.009382
# Age of company in years                         0.009382
# Internet Activity Score                         0.041369
# Employee Count                                  0.043491
# Employees count MoM change                      0.199115
# Last Funding Amount                             0.132535
# Number of Co-founders                           0.121460
# Number of of advisors                           0.095711
# Team size Senior leadership                     0.166963
# Industry trend in investing                     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
df['Employee Count'].corr(df['Team size Senior leadership'])
# Out:
# 0.4971928087809883

# %%
#hence there is,but  not strong  correration between any pair of numberic matrices(except  'age of company in years' and 'year of funding' are strongly correlated.)

# %% [markdown]
# ## dropping columns

# %%
df.iloc[:,:20]
df = df.drop(['year of founding','Company_Name','Short Description of company profile',
             'Industry of company','Investors','Est. Founding Date',
             'Continent of company'],axis = 1)

# %%
start_col = df.columns.get_loc("Number of Co-founders")
df.iloc[:,start_col:start_col + 15]
# Out:
#      Number of Co-founders  Number of of advisors  \
# 0                        1                      2
# 1                        2                      0
# 2                        3                      0
# 3                        2                      0
# 4                        1                      1
# ..                     ...                    ...
# 467                      0                      0
# 468                      0                      0
# 469                      2                      0
# 470                      3                      2
# 471                      3                      0
#
#      Team size Senior leadership Team size all employees  \
# 0                              2                      15
# 1                              4                      20
# 2                              7                      10
# 3                              4                      50
# 4                              8                      40
# ..                           ...                     ...
# 467                            1                 No Info
# 468                            1                 No Info
# 469                            1                 No Info
# 470                            1                 No Info
# 471                            1                 No Info
#
#     Presence of a top angel or venture fund in previous round of investment  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 467                                                 No
# 468                                                 No
# 469                                            No Info
# 470                                            No Info
# 471                                            No Info
#
#     Number of of repeat investors Number of  Sales Support material  \
# 0                               4                           Nothing
# 1                               0                            medium
# 2                               0                               low
# 3                               0                               low
# 4                               0                              high
# ..                            ...                               ...
# 467                             0                           No Info
# 468                             0                           No Info
# 469                       No Info                           No Info
# 470                       No Info                           No Info
# 471                             1                           No Info
#
#     Worked in top companies Average size of companies worked for in the past  \
# 0                        No                                            Small
# 1                       Yes                                            Large
# 2                       Yes                                           Medium
# 3                        No                                            Large
# 4                        No                                            Small
# ..                      ...                                              ...
# 467                 No Info                                          No Info
# 468                 No Info                                          No Info
# 469                 No Info                                          No Info
# 470                 No Info                                          No Info
# 471                 No Info                                          No Info
#
#     Have been part of startups in the past?  \
# 0                                        No
# 1                                       Yes
# 2                                        No
# 3                                       Yes
# 4                                        No
# ..                                      ...
# 467                                 No Info
# 468                                 No Info
# 469                                 No Info
# 470                                 No Info
# 471                                 No Info
#
#     Have been part of successful startups in the past?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 467                                            No Info
# 468                                            No Info
# 469                                            No Info
# 470                                            No Info
# 471                                            No Info
#
#     Was he or she partner in Big 5 consulting? Consulting experience?  \
# 0                                           No                     No
# 1                                           No                     No
# 2                                           No                     No
# 3                                           No                     No
# 4                                           No                     No
# ..                                         ...                    ...
# 467                                    No Info                No Info
# 468                                    No Info                No Info
# 469                                    No Info                No Info
# 470                                    No Info                No Info
# 471                                    No Info                No Info
#
#     Product or service company? Catering to product/service across verticals
# 0                       Service                                           No
# 1                       Product                                           No
# 2                          Both                                          Yes
# 3                       Product                                          Yes
# 4                       Product                                          Yes
# ..                          ...                                          ...
# 467                     Product                                          Yes
# 468                     Service                                           No
# 469                     Service                                           No
# 470                     Service                                          Yes
# 471                     Product                                          Yes
#
# [472 rows x 15 columns]

# %%
start_col = df.columns.get_loc('Catering to product/service across verticals')
df.iloc[:,start_col:start_col+15]
# Out:
#     Catering to product/service across verticals  \
# 0                                             No
# 1                                             No
# 2                                            Yes
# 3                                            Yes
# 4                                            Yes
# ..                                           ...
# 467                                          Yes
# 468                                           No
# 469                                           No
# 470                                          Yes
# 471                                          Yes
#
#     Focus on private or public data? Focus on consumer data?  \
# 0                            Private                      No
# 1                             Public                     Yes
# 2                            Private                     Yes
# 3                             Public                     Yes
# 4                             Public                     Yes
# ..                               ...                     ...
# 467                               no                      No
# 468                               no                      No
# 469                           Public                      No
# 470                           Public                      No
# 471                           Public                      No
#
#     Focus on structured or unstructured data Subscription based business  \
# 0                                       Both                         Yes
# 1                                       Both                          No
# 2                                       Both                         Yes
# 3                                 Structured                         Yes
# 4                                       Both                          No
# ..                                       ...                         ...
# 467                               Structured                          No
# 468                               Structured                          No
# 469                               Structured                         Yes
# 470                               Structured                         Yes
# 471                             Unstructured                         Yes
#
#     Cloud or platform based serive/product? Local or global player  \
# 0                                  Platform                 Global
# 1                                  Platform                  Local
# 2                                     cloud                  Local
# 3                                  Platform                  Local
# 4                                  Platform                  Local
# ..                                      ...                    ...
# 467                                 No Info                  local
# 468                                Platform                 global
# 469                                    Both                 GLOBAL
# 470                                    Both                 GLOBAL
# 471                                    none                 GLOBAL
#
#     Linear or Non-linear business model  \
# 0                                Linear
# 1                            Non-Linear
# 2                            Non-Linear
# 3                            Non-Linear
# 4                            Non-Linear
# ..                                  ...
# 467                          Non-Linear
# 468                              Linear
# 469                          Non-Linear
# 470                              Linear
# 471                          Non-Linear
#
#     Capital intensive business e.g. e-commerce, Engineering products and operations can also cause a business to be capital intensive  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 467                                                 No
# 468                                                Yes
# 469                                                 No
# 470                                                 No
# 471                                                 No
#
#     Number of  of Partners of company Crowdsourcing based business  \
# 0                                 NaN                           No
# 1                                 Few                          Yes
# 2                                 Few                           No
# 3                                 Few                          Yes
# 4                                 Few                           No
# ..                                ...                          ...
# 467                           No Info                           No
# 468                           No Info                           No
# 469                           No Info                           No
# 470                           No Info                           No
# 471                           No Info                           No
#
#     Crowdfunding based business Machine Learning based business  \
# 0                            No                              No
# 1                            No                             Yes
# 2                            No                              No
# 3                            No                              No
# 4                            No                              No
# ..                          ...                             ...
# 467                          No                              No
# 468                          No                              No
# 469                          No                             Yes
# 470                          No                             Yes
# 471                          No                             Yes
#
#     Predictive Analytics business Speech analytics business
# 0                              No                        No
# 1                             Yes                        No
# 2                             Yes                        No
# 3                              No                        No
# 4                              No                        No
# ..                            ...                       ...
# 467                            No                        No
# 468                            No                        No
# 469                           Yes                        No
# 470                           Yes                        No
# 471                           Yes                        No
#
# [472 rows x 15 columns]

# %%
start_col = df.columns.get_loc('Speech analytics business')
df.iloc[:,start_col:start_col+15].head()
# Out:
#   Speech analytics business Prescriptive analytics business Big Data Business  \
# 0                        No                              No                No
# 1                        No                              No               Yes
# 2                        No                              No               Yes
# 3                        No                              No                No
# 4                        No                              No               Yes
#
#   Cross-Channel Analytics/ marketing channels  \
# 0                                          No
# 1                                         Yes
# 2                                          No
# 3                                          No
# 4                                          No
#
#   Owns data or not? (monetization of data) e.g. Factual  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is the company an aggregator/market place? e.g. Bluekai  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Online or offline venture - physical location based business or online venture?  \
# 0                                             Online
# 1                                             Online
# 2                                             Online
# 3                                             Online
# 4                                             Online
#
#   B2C or B2B venture?  \
# 0                 B2C
# 1                 B2C
# 2                 B2B
# 3                 B2C
# 4                 B2B
#
#   Top forums like 'Tech crunch' or 'Venture beat' talking about the company/model - How much is it being talked about?  \
# 0                                               High
# 1                                                Low
# 2                                                Low
# 3                                             Medium
# 4                                                Low
#
#   Average Years of experience for founder and co founder  \
# 0                                               High
# 1                                               High
# 2                                             Medium
# 3                                             Medium
# 4                                               High
#
#   Exposure across the globe Breadth of experience across verticals  \
# 0                       Yes                                    Low
# 1                       Yes                                   High
# 2                       Yes                                    Low
# 3                       Yes                                    Low
# 4                       Yes                                 Medium
#
#   Highest education Years of education  \
# 0           Masters                 21
# 1           Masters                 21
# 2         Bachelors                 18
# 3         Bachelors                 18
# 4         Bachelors                 18
#
#             Specialization of highest education
# 0                                      business
# 1    Supply Chain Management & Entrepreneurship
# 2                                       General
# 3                  Computer Systems Engineering
# 4   Industrial Engineering and Computer Science

# %%
start_col = df.columns.get_loc('Specialization of highest education')
df.iloc[:,start_col:start_col+15].head()
# Out:
#             Specialization of highest education  \
# 0                                      business
# 1    Supply Chain Management & Entrepreneurship
# 2                                       General
# 3                  Computer Systems Engineering
# 4   Industrial Engineering and Computer Science
#
#   Relevance of education to venture Relevance of experience to venture  \
# 0                               Yes                                Yes
# 1                               Yes                                Yes
# 2                               Yes                                Yes
# 3                               Yes                                Yes
# 4                               Yes                                Yes
#
#   Degree from a Tier 1 or Tier 2 university? Renowned in professional circle  \
# 0                                     Tier_1                             500
# 1                                     Tier_1                             500
# 2                                     Tier_2                             500
# 3                                     Tier_2                         No Info
# 4                                        NaN                             500
#
#   Experience in selling and building products  \
# 0                                      Medium
# 1                                        High
# 2                                        High
# 3                                         Low
# 4                                        High
#
#   Experience in Fortune 100 organizations  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
#
#   Experience in Fortune 500 organizations  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
#
#   Experience in Fortune 1000 organizations Top management similarity  \
# 0                                        0                       NaN
# 1                                        0                    Medium
# 2                                        1                    Medium
# 3                                        0                    Medium
# 4                                        0                       Low
#
#   Number of Recognitions for Founders and Co-founders  \
# 0                                                  0
# 1                                                 13
# 2                                                 18
# 3                                                  2
# 4                                                  5
#
#   Number of  of Research publications Skills score Team Composition score  \
# 0                                 NaN            0                    Low
# 1                                 NaN           34                   High
# 2                                 NaN           36                   High
# 3                                 NaN         15.5                 Medium
# 4                                 Few           23                 Medium
#
#   Dificulty of Obtaining Work force
# 0                               Low
# 1                            Medium
# 2                            Medium
# 3                            Medium
# 4                            Medium

# %%
start_col = df.columns.get_loc('Dificulty of Obtaining Work force')
df.iloc[:,start_col:start_col+15].head()
# Out:
#   Dificulty of Obtaining Work force Pricing Strategy Hyper localisation  \
# 0                               Low              Yes                 No
# 1                            Medium              Yes                 No
# 2                            Medium              Yes                 No
# 3                            Medium              Yes                 No
# 4                            Medium              Yes                 No
#
#   Time to market service or product Employee benefits and salary structures  \
# 0                              High                                 No Info
# 1                               Low                                 No Info
# 2                               Low                                 No Info
# 3                               Low                                    Good
# 4                               Low                                     Bad
#
#   Long term relationship with other founders  \
# 0                                         No
# 1                                         No
# 2                                        Yes
# 3                                         No
# 4                                        Yes
#
#   Proprietary or patent position (competitive position)  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Barriers of entry for the competitors Company awards  \
# 0                                   Yes             No
# 1                                   Yes             No
# 2                                   Yes             No
# 3                                   Yes             No
# 4                                   Yes             No
#
#   Controversial history of founder or co founder  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   Legal risk and intellectual property Client Reputation  \
# 0                                   No           No Info
# 1                                  Yes            Medium
# 2                                   No               Low
# 3                                   No               Low
# 4                                   No               Low
#
#   google page rank of company website  \
# 0                             9626884
# 1                             1067034
# 2                               71391
# 3                               11847
# 4                              201814
#
#   Technical proficiencies to analyse and interpret unstructured data  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   Solutions offered
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes

# %%
start_col = df.columns.get_loc('Solutions offered')
df.iloc[:,start_col:start_col+15].head()
# Out:
#   Solutions offered Invested through global incubation competitions?  \
# 0               Yes                                               No
# 1               Yes                                               No
# 2               Yes                                              Yes
# 3               Yes                                              Yes
# 4               Yes                                               No
#
#    Industry trend in investing Disruptiveness of technology  \
# 0                          2.0                          Low
# 1                          3.0                       Medium
# 2                          3.0                       Medium
# 3                          4.0                       Medium
# 4                          3.0                       Medium
#
#   Number of Direct competitors Employees per year of company existence  \
# 0                            0                                     1.5
# 1                            0                             6.666666667
# 2                            0                             3.333333333
# 3                            2                                      10
# 4                            0                                      10
#
#   Last round of funding received (in milionUSD)  \
# 0                                          0.45
# 1                                             5
# 2                                          2.35
# 3                                         10.25
# 4                                           5.5
#
#   Survival through recession, based on existence of the company through recession times  \
# 0                                            No Info
# 1                                     Not Applicable
# 2                                     Not Applicable
# 3                                     Not Applicable
# 4                                     Not Applicable
#
#   Time to 1st investment (in months)  \
# 0                            No Info
# 1                                 10
# 2                                  2
# 3                                  1
# 4                                 13
#
#   Avg time to investment - average across all rounds, measured from previous investment  \
# 0                                              11.56
# 1                                                  9
# 2                                        7.344444444
# 3                                                8.7
# 4                                        9.822222222
#
#   Gartner hype cycle stage Time to maturity of technology (in years)  \
# 0                      NaN                                       NaN
# 1                   Trough                                    2 to 5
# 2                   Trough                                    2 to 5
# 3                   Trough                                    2 to 5
# 4                      NaN                                       NaN
#
#   Percent_skill_Entrepreneurship Percent_skill_Operations  \
# 0                              0                        0
# 1                    15.88235294              11.76470588
# 2                    9.401709402                        0
# 3                              0                        0
# 4                              0                        0
#
#   Percent_skill_Engineering
# 0                         0
# 1                        15
# 2               57.47863248
# 3                         0
# 4                         0

# %%
start_col = df.columns.get_loc('Percent_skill_Engineering')
df.iloc[:,start_col:start_col+15].head()
# Out:
#   Percent_skill_Engineering Percent_skill_Marketing Percent_skill_Leadership  \
# 0                         0                       0                        0
# 1                        15             12.94117647                        0
# 2               57.47863248                       0                        0
# 3                         0                       0                        0
# 4                         0                       0                        0
#
#   Percent_skill_Data Science Percent_skill_Business Strategy  \
# 0                          0                               0
# 1                8.823529412                     21.76470588
# 2                3.846153846                     17.09401709
# 3                          0                               0
# 4                          0                               0
#
#   Percent_skill_Product Management Percent_skill_Sales Percent_skill_Domain  \
# 0                                0                   0                    0
# 1                      10.88235294         2.941176471                    0
# 2                      9.401709402                   0          2.777777778
# 3                                0                   0                    0
# 4                                0                   0                    0
#
#   Percent_skill_Law Percent_skill_Consulting Percent_skill_Finance  \
# 0                 0                        0                     0
# 1                 0                        0                     0
# 2                 0                        0                     0
# 3                 0                        0                     0
# 4                 0                        0                     0
#
#   Percent_skill_Investment Renown score
# 0                        0            0
# 1                        0            8
# 2                        0            9
# 3                        0            5
# 4                        0            6

# %%
import pandas as pd

# Assuming your DataFrame is named `df`

# Count the number of NaN values in each row
nan_count = df.isna().sum(axis=1)

# Add this count as a new column for reference (optional)
df['NaN_Count'] = nan_count

# Find the rows with the most NaN values
most_nan_rows = df.loc[nan_count.nlargest(5).index]  # Adjust `5` for the top N rows

# Display the rows with the most NaN values
most_nan_rows
# Out:
#     Dependent-Company Status Age of company in years  Internet Activity Score  \
# 286                   Failed                       2                      NaN
# 348                  Success                 No Info                      NaN
# 401                   Failed                     NaN                      NaN
# 404                   Failed                     NaN                      NaN
# 407                   Failed                     NaN                      NaN
#
#     Focus functions of company  Employee Count  Employees count MoM change  \
# 286                       game             NaN                         NaN
# 348     mobile app development             NaN                         NaN
# 401                        NaN             NaN                         NaN
# 404                        NaN             NaN                         NaN
# 407                        NaN             NaN                         NaN
#
#     Has the team size grown Last Funding Date  Last Funding Amount  \
# 286                      No               NaN                  NaN
# 348                     yes               NaN                  NaN
# 401                     NaN               NaN                  NaN
# 404                     NaN               NaN                  NaN
# 407                     NaN               NaN                  NaN
#
#     Country of company  ... Percent_skill_Business Strategy  \
# 286                NaN  ...                               0
# 348                NaN  ...                     11.76470588
# 401                NaN  ...                         No Info
# 404                NaN  ...                     5.882352941
# 407                NaN  ...                         No Info
#
#     Percent_skill_Product Management  Percent_skill_Sales  \
# 286                                0                    0
# 348                      5.882352941          5.882352941
# 401                          No Info              No Info
# 404                      11.76470588                    0
# 407                          No Info              No Info
#
#      Percent_skill_Domain  Percent_skill_Law Percent_skill_Consulting  \
# 286                     0                  0                        0
# 348           5.882352941                  0              5.882352941
# 401               No Info            No Info                  No Info
# 404           5.882352941                  0                        0
# 407               No Info            No Info                  No Info
#
#     Percent_skill_Finance Percent_skill_Investment Renown score NaN_Count
# 286                     0                        0            0        14
# 348                     0                        0            6        13
# 401               No Info                  No Info      No Info        13
# 404           5.882352941                        0            8        13
# 407               No Info                  No Info      No Info        13
#
# [5 rows x 110 columns]

# %%
df.replace('No Info', np.nan, inplace=True)
nan_mask = df.isna()

# %%
import pandas as pd

# Assuming your DataFrame is named `df`

# Count the number of NaN values in each row
nan_count = df.isna().sum(axis=1)

# Add this count as a new column for reference (optional)
df['NaN_Count'] = nan_count

# Find the rows with the most NaN values
most_nan_rows = df.loc[nan_count.nlargest(5).index]  # Adjust `5` for the top N rows

# Display the rows with the most NaN values
most_nan_rows
# Out:
#     Dependent-Company Status Age of company in years  Internet Activity Score  \
# 423                   Failed                       6                    -89.0
# 425                   Failed                     NaN                      7.0
# 464                   Failed                       4                      0.0
# 422                   Failed                     NaN                      NaN
# 462                   Failed                       3                     -5.0
#
#     Focus functions of company  Employee Count  Employees count MoM change  \
# 423                        NaN             6.0                         0.0
# 425                        NaN             NaN                         NaN
# 464        CAMPAIGN MANAGEMENT             0.0                         NaN
# 422          Sales & Marketing             NaN                         NaN
# 462                        NaN             NaN                         NaN
#
#     Has the team size grown Last Funding Date  Last Funding Amount  \
# 423                      No         8/14/2012            4700000.0
# 425                     NaN               NaN                  NaN
# 464                     NaN               NaN                  NaN
# 422                      No               NaN                  NaN
# 462                      No               NaN                  NaN
#
#     Country of company  ... Percent_skill_Business Strategy  \
# 423      United States  ...                             NaN
# 425             Canada  ...                             NaN
# 464      United States  ...                             NaN
# 422                NaN  ...                             NaN
# 462      United States  ...                             NaN
#
#     Percent_skill_Product Management  Percent_skill_Sales  \
# 423                              NaN                  NaN
# 425                              NaN                  NaN
# 464                              NaN                  NaN
# 422                              NaN                  NaN
# 462                              NaN                  NaN
#
#      Percent_skill_Domain  Percent_skill_Law Percent_skill_Consulting  \
# 423                   NaN                NaN                      NaN
# 425                   NaN                NaN                      NaN
# 464                   NaN                NaN                      NaN
# 422                   NaN                NaN                      NaN
# 462                   NaN                NaN                      NaN
#
#     Percent_skill_Finance Percent_skill_Investment Renown score NaN_Count
# 423                   NaN                      NaN          NaN        78
# 425                   NaN                      NaN          NaN        77
# 464                   NaN                      NaN          NaN        77
# 422                   NaN                      NaN          NaN        76
# 462                   NaN                      NaN          NaN        76
#
# [5 rows x 110 columns]

# %%
plt.figure(figsize=(20, 10))  # Adjust size as needed
sns.heatmap(nan_mask, cbar=True, cmap="YlGnBu", yticklabels=False)

plt.title('Heatmap of Missing Data (NaN and No Info)', fontsize=16)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Rows', fontsize=12)
plt.show()

# %%
import pandas as pd

# Count the number of NaN values in each row
nan_count = df.isna().sum(axis=1)

# Count rows where the NaN count is greater than 80
rows_with_more_than_80_nan = (nan_count > 80).sum()

print(f"Number of rows with more than 80 NaN values: {rows_with_more_than_80_nan}")
# Out:
# Number of rows with more than 80 NaN values: 5

# %%
# Filter out rows where the count of NaN values is greater than 80
df_cleaned = df[nan_count <= 80]

# Optionally reset the index of the resulting DataFrame
df_cleaned.reset_index(drop=True, inplace=True)

print(f"Original DataFrame had {len(df)} rows.")
print(f"Cleaned DataFrame has {len(df_cleaned)} rows.")
df = df_cleaned
# Out:
# Original DataFrame had 472 rows.
# Cleaned DataFrame has 467 rows.

# %%
df.shape
# Out:
# (467, 110)

# %%
df['Dependent-Company Status'].value_counts()
# Out:
# Dependent-Company Status
# Success    305
# Failed     162
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20, 10))  # Adjust size as needed
sns.heatmap(nan_mask, cbar=True, cmap="YlGnBu", yticklabels=False)

plt.title('Heatmap of Missing Data (NaN and No Info)', fontsize=16)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Rows', fontsize=12)
plt.show()

# %%
df.head(50)
# Out:
#    Dependent-Company Status Age of company in years  Internet Activity Score  \
# 0                   Success                       3                    455.0
# 1                   Success                       5                    -99.0
# 2                   Success                       4                    496.0
# 3                   Success                       4                    106.0
# 4                   Success                       3                     39.0
# 5                   Success                       4                    139.0
# 6                   Success                       3                    306.0
# 7                   Success                       1                     53.0
# 8                   Success                       3                    762.0
# 9                   Success                       4                    140.0
# 10                  Success                       4                    115.0
# 11                  Success                       6                    277.0
# 12                  Success                       4                    242.0
# 13                  Success                       6                    533.0
# 14                  Success                       4                    -81.0
# 15                  Success                       5                    471.0
# 16                  Success                      12                     47.0
# 17                  Success                       4                     70.0
# 18                  Success                       9                    242.0
# 19                  Success                       2                    245.0
# 20                  Success                       2                    373.0
# 21                  Success                       3                     61.0
# 22                  Success                       5                    155.0
# 23                  Success                       1                     43.0
# 24                  Success                       7                     11.0
# 25                  Success                       2                    281.0
# 26                  Success                       2                    421.0
# 27                  Success                       6                    -91.0
# 28                  Success                       4                    983.0
# 29                  Success                       2                     75.0
# 30                  Success                       4                     56.0
# 31                  Success                       2                     89.0
# 32                  Success                       3                    374.0
# 33                  Success                       6                     40.0
# 34                  Success                       3                    805.0
# 35                  Success                       5                   -129.0
# 36                  Success                       2                    888.0
# 37                  Success                       2                    272.0
# 38                  Success                       2                    124.0
# 39                  Success                       5                    409.0
# 40                  Success                       2                    388.0
# 41                  Success                       5                    157.0
# 42                  Success                       5                     43.0
# 43                  Success                       2                    217.0
# 44                  Success                       1                    181.0
# 45                  Success                       4                    372.0
# 46                  Success                       4                    263.0
# 47                  Success                       3                    138.0
# 48                  Success                       3                    401.0
# 49                  Success                       5                     -2.0
#
#    Focus functions of company  Employee Count  Employees count MoM change  \
# 0                  operations            14.0                         0.0
# 1           Marketing & Sales            45.0                        10.0
# 2           Marketing & Sales            39.0                         3.0
# 3                   analytics            14.0                         8.0
# 4                    Research             7.0                         0.0
# 5                   Computing            29.0                       -12.0
# 6                   Marketing            16.0                        45.0
# 7                    Research             3.0                         NaN
# 8            Sales, marketing            34.0                         0.0
# 9                  operations            31.0                         3.0
# 10          Marketing \nsales            47.0                         7.0
# 11                 Technology            22.0                         0.0
# 12           marketing, sales            13.0                         0.0
# 13            Data Management           129.0                         8.0
# 14                  Marketing            23.0                         0.0
# 15          Marketing & Sales            52.0                        -4.0
# 16         Solution providing            46.0                         2.0
# 17                  Marketing            27.0                         0.0
# 18               Social Media             NaN                         NaN
# 19                  Marketing            32.0                         3.0
# 20       Community Betterment             3.0                         0.0
# 21              Web Analytics             5.0                         0.0
# 22                   Strategy             5.0                         0.0
# 23               Social Media             NaN                         NaN
# 24                   Strategy             NaN                         NaN
# 25                    Bug fix             3.0                         0.0
# 26           Data Integration             7.0                         0.0
# 27         malware protection            39.0                        -7.0
# 28                  Analytics           115.0                         6.0
# 29                  Marketing            14.0                         0.0
# 30                  Analytics             7.0                         0.0
# 31                  Marketing             6.0                         0.0
# 32                 Operations            57.0                        -3.0
# 33                      Sales            12.0                         0.0
# 34   Marketing, Web Analytics            23.0                         0.0
# 35                  Marketing            50.0                         0.0
# 36                  Marketing            38.0                        23.0
# 37                  marketing            24.0                         0.0
# 38                  analytics            13.0                         0.0
# 39                  analytics            22.0                        -4.0
# 40                      sales            17.0                         6.0
# 41                 mobile app            43.0                         2.0
# 42                   analytic             6.0                         0.0
# 43                   analytic             2.0                         0.0
# 44                  software              9.0                         0.0
# 45    SOCIAL MEDIA management            41.0                         3.0
# 46                  MARKETING            18.0                        29.0
# 47            customer servce            14.0                       -13.0
# 48           CUSTOMER SERVICE            18.0                         6.0
# 49                 OPERATIONS            20.0                         5.0
#
#    Has the team size grown Last Funding Date  Last Funding Amount  \
# 0                       No        10/23/2013            2350000.0
# 1                       No         5/10/2012           10250000.0
# 2                       No        12/11/2013            5500000.0
# 3                       No         9/17/2013            1000000.0
# 4                       No          9/3/2013            2000000.0
# 5                       No         11/8/2012            6700000.0
# 6                       No         2/26/2014           11000000.0
# 7                       No        10/24/2013            3000000.0
# 8                       No         8/13/2013           16000000.0
# 9                       No         6/27/2012            6300000.0
# 10                      No         9/10/2013           11500000.0
# 11                      No          1/3/2012            6500000.0
# 12                      No        11/11/2013            2800000.0
# 13                     Yes         1/27/2014           41000000.0
# 14                      No        12/14/2012            3499999.0
# 15                      No        10/17/2013           10000000.0
# 16                     Yes        12/14/2012             750000.0
# 17                     Yes          5/6/2011            5000000.0
# 18                     Yes         3/13/2013            1500000.0
# 19                     Yes         1/29/2014           15000000.0
# 20                     Yes         11/1/2013            1700000.0
# 21                     Yes          8/1/2011             250000.0
# 22                     Yes        12/12/2013            1400000.0
# 23                      No          7/1/2013            1100000.0
# 24                     yes         4/30/2013           15000000.0
# 25                      No          4/1/2013             200000.0
# 26                      No         1/15/2013             600000.0
# 27                      No         9/22/2011                  NaN
# 28                     yes         3/18/2014           20000000.0
# 29                     yes         5/24/2013            2870890.0
# 30                      No        10/23/2012             450000.0
# 31                      No          6/1/2013                  NaN
# 32                     Yes          8/1/2010              60000.0
# 33                     Yes          7/8/2013            2517424.0
# 34                     yes         12/3/2013            4000000.0
# 35                     yes         6/13/2011           13000000.0
# 36                     yes          2/4/2014            6500000.0
# 37                      No         6/25/2013            1000000.0
# 38                      No          8/7/2013            2000000.0
# 39                     yes          5/9/2013            3900000.0
# 40                      No          7/3/2013             750000.0
# 41                     yes          6/7/2013                  NaN
# 42                      No        10/15/2009             425000.0
# 43                      No          9/1/2013              30000.0
# 44                      No         8/30/2013             135000.0
# 45                      No          5/3/2011            1300000.0
# 46                     YES        11/12/2013            1900000.0
# 47                     YES         2/19/2014            1000000.0
# 48                     YES          6/6/2013            1800000.0
# 49                      No         3/19/2012            3000000.0
#
#    Country of company  ... Percent_skill_Business Strategy  \
# 0       United States  ...                     17.09401709
# 1       United States  ...                               0
# 2       United States  ...                               0
# 3       United States  ...                            6.25
# 4       United States  ...                               0
# 5       United States  ...                               0
# 6       United States  ...                     19.77124183
# 7       United States  ...                               0
# 8       United States  ...                     7.692307692
# 9       United States  ...                     36.36363636
# 10      United States  ...                               0
# 11      United States  ...                     4.166666667
# 12      United States  ...                     6.666666667
# 13      United States  ...                     27.77777778
# 14      United States  ...                              25
# 15      United States  ...                              20
# 16      United States  ...                               0
# 17      United States  ...                     27.77777778
# 18      United States  ...                     33.33333333
# 19      United States  ...                     14.21568627
# 20      United States  ...                     25.65359477
# 21      United States  ...                     7.692307692
# 22      United States  ...                               0
# 23      United States  ...                     7.142857143
# 24      United States  ...                     22.22222222
# 25      United States  ...                     11.45833333
# 26      United States  ...                               0
# 27      United States  ...                     12.77777778
# 28      United States  ...                            6.25
# 29      United States  ...                     27.77777778
# 30      United States  ...                     11.83706816
# 31      United States  ...                     11.11111111
# 32      United States  ...                     38.88888889
# 33      United States  ...                           18.75
# 34      United States  ...                     11.76470588
# 35      United States  ...                     22.22222222
# 36      United States  ...                               0
# 37      United States  ...                     11.11111111
# 38      United States  ...                     11.11111111
# 39      United States  ...                               0
# 40              India  ...                     5.882352941
# 41      United States  ...                     23.61111111
# 42            Belgium  ...                               0
# 43           Bulgaria  ...                               0
# 44           Bulgaria  ...                     11.11111111
# 45             France  ...                     4.545454545
# 46             France  ...                               0
# 47     United Kingdom  ...                     3.333333333
# 48     United Kingdom  ...                               0
# 49     United Kingdom  ...                     15.78947368
#
#    Percent_skill_Product Management  Percent_skill_Sales  \
# 0                       9.401709402                    0
# 1                                 0                    0
# 2                                 0                    0
# 3                             3.125                3.125
# 4                                 0                    0
# 5                                 0                    0
# 6                       2.777777778          2.777777778
# 7                                 0                    0
# 8                                 0          3.846153846
# 9                       9.090909091                    0
# 10                                0                    0
# 11                      4.166666667          4.166666667
# 12                                0                    0
# 13                                0          11.11111111
# 14                                0                    0
# 15                                0                    0
# 16                                0                    0
# 17                      5.555555556                    0
# 18                      8.333333333          8.333333333
# 19                      4.044117647          4.044117647
# 20                      2.777777778           11.2745098
# 21                                0          7.692307692
# 22                                0                    0
# 23                      7.142857143          7.142857143
# 24                      5.555555556          22.22222222
# 25                                0                    0
# 26                                0                    0
# 27                                0                    0
# 28                                0                 6.25
# 29                                0          5.555555556
# 30                      1.111111111          3.333333333
# 31                      2.777777778                    0
# 32                                0                    0
# 33                             6.25                    0
# 34                      5.882352941                    0
# 35                      11.11111111                    0
# 36                                0                    0
# 37                      5.555555556          5.555555556
# 38                                0          5.555555556
# 39                                0                    0
# 40                                0          11.76470588
# 41                      8.680555556                 6.25
# 42                                0                    0
# 43                                0                    0
# 44                      11.11111111                    0
# 45                      9.090909091                    0
# 46                                0                    0
# 47                      2.941176471          3.333333333
# 48                                0                    0
# 49                      5.263157895          5.263157895
#
#     Percent_skill_Domain  Percent_skill_Law Percent_skill_Consulting  \
# 0            2.777777778                  0                        0
# 1                      0                  0                        0
# 2                      0                  0                        0
# 3                      0                  0                        0
# 4            5.555555556                  0                        0
# 5                      0                  0                        0
# 6                      0                  0                        0
# 7            20.83333333                  0                        0
# 8                      0                  0                        0
# 9                      0                  0                        0
# 10                     0                  0                        0
# 11                     0                  0                        0
# 12                     0                  0                        0
# 13           5.555555556                  0                        0
# 14           8.333333333                  0                        0
# 15                     0                  0                        0
# 16                     0                  0                        0
# 17           5.555555556                  0                        0
# 18                     0                  0              16.66666667
# 19           4.166666667                  0                        0
# 20           2.777777778                  0                        0
# 21           15.38461538                  0                        0
# 22                     0                  0                        0
# 23                     0        14.28571429                        0
# 24           5.555555556                  0                        0
# 25                     0                  0                        0
# 26                     0                  0                        0
# 27           2.777777778        6.111111111                        0
# 28                     0                  0                        0
# 29                     0                  0                        0
# 30           4.892623716                  0              1.111111111
# 31           8.333333333                  0                        0
# 32           16.66666667                  0                        0
# 33                     0                  0                        0
# 34           17.64705882                  0                        0
# 35           11.11111111                  0                        0
# 36                     0                  0                        0
# 37                     0                  0                        0
# 38                     0                  0                        0
# 39                     0                  0                        0
# 40           5.882352941                  0                        0
# 41           8.680555556                  0                        0
# 42                     0                  0                        0
# 43                     0                  0                        0
# 44                     0                  0              11.11111111
# 45                     0                  0                        0
# 46                     0                  0                        0
# 47           9.215686275                  0                        0
# 48                     0                  0                        0
# 49           10.52631579                  0                        0
#
#    Percent_skill_Finance Percent_skill_Investment Renown score NaN_Count
# 0                      0                        0            9         2
# 1                      0                        0            5         2
# 2                      0                        0            6         3
# 3                      0                        0            6         2
# 4                      0                        0            0         4
# 5                      0                        0            2         0
# 6                      0              5.555555556            5         2
# 7                      0                        0            4         4
# 8                      0                        0            6         4
# 9                      0                        0            0         3
# 10                     0                        0            0         2
# 11                     0                        0            0         3
# 12                     0                        0            1         3
# 13           5.555555556              5.555555556            5         1
# 14                     0                        0            2         1
# 15                     0                        0            0         1
# 16                     0                        0            5         4
# 17                     0                        0            7         3
# 18                     0                        0            0         3
# 19                     0              2.083333333            9         2
# 20                     0              5.718954248            3         2
# 21                     0                        0            0         3
# 22                     0                        0            0         2
# 23                     0              7.142857143            4         3
# 24                     0                        0            1         4
# 25                     0                        0            5         2
# 26                     0                        0            2         3
# 27                     0                        0            4         3
# 28                     0                        0            1         1
# 29           11.11111111              5.555555556            0         2
# 30           4.444444444              1.111111111            5         4
# 31                     0                        0            3         4
# 32                     0                        0            2         4
# 33                     0                     6.25            9         4
# 34                     0                        0            3         5
# 35                     0                        0            0         4
# 36                     0                        0            4         3
# 37                     0              5.555555556            0         4
# 38           5.555555556                        0            6         4
# 39                     0                        0            4         4
# 40           5.882352941                        0            1         3
# 41                     0                        0            8         4
# 42                     0                        0            2         5
# 43                     0                        0            3         3
# 44                     0                        0            1         4
# 45                     0                        0            7         3
# 46                     0                        0            1         2
# 47                     0                        0            6         5
# 48                     0                        0            0         5
# 49                     0              5.263157895            7         1
#
# [50 rows x 110 columns]

# %%
# Count the number of NaN values in each column
nan_counts = df.isna().sum()

# Sort columns by the number of NaN values in descending order
nan_counts_sorted = nan_counts.sort_values(ascending=False)

# Display the top columns with the most NaN values
print("Columns with the most NaN values:")
print(nan_counts_sorted.head(10))  # Adjust the number to show more or fewer columns
# Out:
# Columns with the most NaN values:
# Number of  of Partners of company             380
# Employee benefits and salary structures       346
# Number of  of Research publications           329
# Top management similarity                     277
# Client Reputation                             269
# Degree from a Tier 1 or Tier 2 university?    227
# Employees count MoM change                    203
# Time to maturity of technology (in years)     167
# Gartner hype cycle stage                      167
# Employee Count                                164
# dtype: int64

# %%
# Count the number of NaN values in each column
#nan_counts = df.isna().sum()

# Identify the top 10 columns with the most NaN values
columns_to_drop = nan_counts.nlargest(5).index

# Drop those columns from the DataFrame
df_cleaned = df.drop(columns=columns_to_drop)
df_cleaned
# Out:
#     Dependent-Company Status Age of company in years  Internet Activity Score  \
# 0                    Success                     NaN                     -1.0
# 1                    Success                       3                    125.0
# 2                    Success                       3                    455.0
# 3                    Success                       5                    -99.0
# 4                    Success                       4                    496.0
# ..                       ...                     ...                      ...
# 462                   Failed                       3                     -5.0
# 463                   Failed                     NaN                      NaN
# 464                   Failed                       4                      0.0
# 465                   Failed                       5                      0.0
# 466                   Failed                       1                     11.0
#
#     Focus functions of company  Employee Count  Employees count MoM change  \
# 0                    operation             3.0                         0.0
# 1             Marketing, sales             NaN                         NaN
# 2                   operations            14.0                         0.0
# 3            Marketing & Sales            45.0                        10.0
# 4            Marketing & Sales            39.0                         3.0
# ..                         ...             ...                         ...
# 462                        NaN             NaN                         NaN
# 463               consumer web             NaN                         NaN
# 464        CAMPAIGN MANAGEMENT             0.0                         NaN
# 465       SOCIALMEDIA CAMPAIGN             NaN                         NaN
# 466         DATA VISUALIZATION             NaN                         NaN
#
#     Has the team size grown Last Funding Date  Last Funding Amount  \
# 0                        No         5/26/2013             450000.0
# 1                        No               NaN                  NaN
# 2                        No        10/23/2013            2350000.0
# 3                        No         5/10/2012           10250000.0
# 4                        No        12/11/2013            5500000.0
# ..                      ...               ...                  ...
# 462                      No               NaN                  NaN
# 463                      No               NaN                  NaN
# 464                     NaN               NaN                  NaN
# 465                     NaN          2/1/2010             100000.0
# 466                     NaN          9/1/2013             120000.0
#
#     Country of company  ... Percent_skill_Business Strategy  \
# 0        United States  ...                               0
# 1        United States  ...                     21.76470588
# 2        United States  ...                     17.09401709
# 3        United States  ...                               0
# 4        United States  ...                               0
# ..                 ...  ...                             ...
# 462      United States  ...                             NaN
# 463                NaN  ...                               0
# 464      United States  ...                             NaN
# 465      United States  ...                             NaN
# 466      United States  ...                             NaN
#
#     Percent_skill_Product Management  Percent_skill_Sales  \
# 0                                  0                    0
# 1                        10.88235294          2.941176471
# 2                        9.401709402                    0
# 3                                  0                    0
# 4                                  0                    0
# ..                               ...                  ...
# 462                              NaN                  NaN
# 463                                0                    0
# 464                              NaN                  NaN
# 465                              NaN                  NaN
# 466                              NaN                  NaN
#
#      Percent_skill_Domain  Percent_skill_Law Percent_skill_Consulting  \
# 0                       0                  0                        0
# 1                       0                  0                        0
# 2             2.777777778                  0                        0
# 3                       0                  0                        0
# 4                       0                  0                        0
# ..                    ...                ...                      ...
# 462                   NaN                NaN                      NaN
# 463                     0                  0                        0
# 464                   NaN                NaN                      NaN
# 465                   NaN                NaN                      NaN
# 466                   NaN                NaN                      NaN
#
#     Percent_skill_Finance Percent_skill_Investment Renown score NaN_Count
# 0                       0                        0            0        10
# 1                       0                        0            8         6
# 2                       0                        0            9         2
# 3                       0                        0            5         2
# 4                       0                        0            6         3
# ..                    ...                      ...          ...       ...
# 462                   NaN                      NaN          NaN        76
# 463                     0                        0            0        62
# 464                   NaN                      NaN          NaN        77
# 465                   NaN                      NaN          NaN        76
# 466                   NaN                      NaN          NaN        73
#
# [467 rows x 105 columns]

# %%
df['Renown score'].nunique()
# Out:
# 13

# %%
df['Renown score'] = pd.to_numeric(df['Renown score'],errors = 'coerce')
df['Renown score'].dtype
# Out:
# dtype('float64')

# %%
df['Dependent-Company Status'].unique()
# Out:
# array(['Success', 'Failed'], dtype=object)

# %%
df['Dependent-Company Status'] = df['Dependent-Company Status'].map({'Success':1,'Failed':0})

# %%
df['Dependent-Company Status'].tail(5)
# Out:
# 467    0
# 468    0
# 469    0
# 470    0
# 471    0
# Name: Dependent-Company Status, dtype: int64

# %%
print(df[['Renown score', 'Dependent-Company Status']].corr())
# Out:
#                           Renown score  Dependent-Company Status
# Renown score                   1.00000                  -0.06292
# Dependent-Company Status      -0.06292                   1.00000

# %%
#rule of thumb suggests every feature should have 10 observation for model performing,so in our case
#for 472 observations we can leave 47 features out of 116.in models like d-trees.or random_forest number 
#of features can be much more
